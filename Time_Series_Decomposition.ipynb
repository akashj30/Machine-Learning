# %% [markdown]
# <a href="https://colab.research.google.com/github/akashj30/Machine-Learning/blob/main/Time_Series_Decomposition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Time Series Decomposition

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Read the data

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/utkarshg1/Neural-Net-Datasets/main/AirPassengers.csv"
df = pd.read_csv(url, parse_dates=True, index_col="Month")
df.head()
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %% [markdown]
# ### Visualizing above data

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.plot(df["Passengers"])
plt.xlabel("Months")
plt.ylabel("Passengers")
plt.title("Air Passengers Monthly")
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Choose Multiplicative model from above

# %% [markdown]
# ### Decompose the time series

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
Q = seasonal_decompose(
    df["Passengers"],
    model="multiplicative",
    period=12
)
Q.plot()

# %%
Q.observed
# Out:
# Month
# 1949-01-01    112.0
# 1949-02-01    118.0
# 1949-03-01    132.0
# 1949-04-01    129.0
# 1949-05-01    121.0
#               ...
# 1960-08-01    606.0
# 1960-09-01    508.0
# 1960-10-01    461.0
# 1960-11-01    390.0
# 1960-12-01    432.0
# Name: Passengers, Length: 144, dtype: float64

# %%
Q.trend[10:]
# Out:
# Month
# 1949-11-01    129.000000
# 1949-12-01    129.750000
# 1950-01-01    131.250000
# 1950-02-01    133.083333
# 1950-03-01    134.916667
#                  ...
# 1960-08-01           NaN
# 1960-09-01           NaN
# 1960-10-01           NaN
# 1960-11-01           NaN
# 1960-12-01           NaN
# Name: trend, Length: 134, dtype: float64

# %%
Q.seasonal
# Out:
# Month
# 1949-01-01    0.910230
# 1949-02-01    0.883625
# 1949-03-01    1.007366
# 1949-04-01    0.975906
# 1949-05-01    0.981378
#                 ...
# 1960-08-01    1.219911
# 1960-09-01    1.060492
# 1960-10-01    0.921757
# 1960-11-01    0.801178
# 1960-12-01    0.898824
# Name: seasonal, Length: 144, dtype: float64

# %%
Q.resid[10:]
# Out:
# Month
# 1949-11-01    1.006270
# 1949-12-01    1.011812
# 1950-01-01    0.962603
# 1950-02-01    1.071467
# 1950-03-01    1.037447
#                 ...
# 1960-08-01         NaN
# 1960-09-01         NaN
# 1960-10-01         NaN
# 1960-11-01         NaN
# 1960-12-01         NaN
# Name: resid, Length: 134, dtype: float64

# %% [markdown]
# ### Trend

# %%
plt.figure(figsize=(10, 5))
Q.observed.plot()
Q.trend.plot()
plt.xlabel("Month")
plt.ylabel("Passengers")
plt.title("Trend Analysis")
plt.show()

# %%
plt.figure(figsize=(10, 5))
Q.seasonal.plot()
plt.xlabel("Month")
plt.ylabel("Season")
plt.title("Seasonal Analysis")
plt.show()

# %%
plt.figure(figsize=(10, 5))
Q.resid.plot()
plt.xlabel("Month")
plt.ylabel("Residuals")
plt.title("Residual Analysis")
plt.show()
